# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
os.chdir('/content/drive/My Drive/crnn.pytorch')

# %%
# !ls
# Out:
# '=1.2.0'      demo.py	   ocr.ipynb	 requirements.txt   train.py
#  data	      LICENSE.md   __pycache__	 test		    utils.py
#  dataset.py   models	   README.md	 tool

# %%
# !cat requirements.txt
# Out:
# lmdb==0.97
# Pillow==6.1.0
# six==1.12.0
# torch==1.2.0
# torchvision==0.4.0

# %%
# !pip install torch>=1.2.0

# %%
# !pip install torchvision==0.4.0

# %%
# !pip install lmdb==0.97

# %%
# !cat demo.py

# %%
# !ls
# Out:
# '=1.2.0'      demo.py	   ocr.ipynb	 requirements.txt   train.py
#  data	      LICENSE.md   __pycache__	 test		    utils.py
#  dataset.py   models	   README.md	 tool

# %%
# !python demo.py
# Out:
# loading image path ./data/r0.jpg
# loading pretrained model from ./data/crnn.pth
# n---a-m-e-y-o-u-w--a-ntt-- => nameyouwant
